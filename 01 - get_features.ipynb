# %%
import os

path = '/Users/gustavosganzerla/Documents/arp/sequences/'
path_out = '/Users/gustavosganzerla/Documents/arp/sequences/physical_analysis/'

filenames = os.listdir(path)


for item in filenames:
	if '.txt' in item:
		with open(path+item, 'r') as f:



			list_stability = []
			for sequence in f:
				size = len(sequence)
				enthalpy=0


				for pos in range(size-1):
					if sequence.upper()[pos:pos+2]== 'AA':
						stability=-1
						list_stability.append(stability)

					if sequence.upper()[pos:pos+2]== 'AT':
						stability=-0.88
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'TA':
						stability=-0.58
						stacking=-3.82
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'AG':
						stability=-1.3
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'GA':
						stability=-1.3
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'TT':
						stability=-1
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'AC':
						stability=-1.45
						list_stability.append(stability)

					if sequence.upper()[pos:pos+2]== 'CA':
						stability=-1.45
						stacking=6.57
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'TG':
						stability=-1.44
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'GT':
						stability=-1.44
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'TC':
						stability=-1.28
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'CT':
						stability=-1.28
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'CC':
						stability=-1.84
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'CG':
						stability=-2.24
						list_stability.append(stability)

					if sequence.upper()[pos:pos+2]== 'GC':
						stability=-2.27
						list_stability.append(stability)


					if sequence.upper()[pos:pos+2]== 'GG':
						stability=-1.84
						list_stability.append(stability)


			with open(path_out+"stability_"+item, 'a+') as out:
				for element in list_stability:
					out.write(str(element) + "\n")




			

f.close()
out.close()

# %%
pip install jupyterthemes
# Out:
# Collecting jupyterthemes
#   Using cached jupyterthemes-0.20.0-py2.py3-none-any.whl (7.0 MB)
# Requirement already satisfied: ipython>=5.4.1 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jupyterthemes) (7.31.1)
# Requirement already satisfied: notebook>=5.6.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jupyterthemes) (6.4.8)
# Requirement already satisfied: jupyter-core in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jupyterthemes) (4.9.2)
# Collecting lesscpy>=0.11.2
#   Using cached lesscpy-0.15.0-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: matplotlib>=1.4.3 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jupyterthemes) (3.5.1)
# Requirement already satisfied: matplotlib-inline in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (61.2.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: pygments in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (2.11.2)
# Requirement already satisfied: appnope in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (0.1.2)
# Requirement already satisfied: decorator in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (0.18.1)
# Requirement already satisfied: backcall in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 10.2 MB/s eta 0:00:01
# Requirement already satisfied: six in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from lesscpy>=0.11.2->jupyterthemes) (1.16.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from matplotlib>=1.4.3->jupyterthemes) (9.0.1)
# Requirement already satisfied: numpy>=1.17 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from matplotlib>=1.4.3->jupyterthemes) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from matplotlib>=1.4.3->jupyterthemes) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from matplotlib>=1.4.3->jupyterthemes) (21.3)
# Requirement already satisfied: nbconvert in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (6.4.4)
# Requirement already satisfied: nbformat in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (5.3.0)
# Requirement already satisfied: tornado>=6.1 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (6.1)
# Requirement already satisfied: ipython-genutils in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: ipykernel in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (6.9.1)
# Requirement already satisfied: prometheus-client in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (0.13.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (6.1.12)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (0.13.1)
# Requirement already satisfied: jinja2 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (2.11.3)
# Requirement already satisfied: pyzmq>=17 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (22.3.0)
# Requirement already satisfied: argon2-cffi in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from notebook>=5.6.0->jupyterthemes) (1.5.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from pexpect>4.3->ipython>=5.4.1->jupyterthemes) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.5)
# Requirement already satisfied: typing-extensions in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (4.1.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.0)
# Requirement already satisfied: pycparser in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from ipykernel->notebook>=5.6.0->jupyterthemes) (1.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.0.1)
# Requirement already satisfied: bleach in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: testpath in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.1.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.4.0)
# Requirement already satisfied: fastjsonschema in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (5.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (21.4.0)
# Requirement already satisfied: importlib-metadata in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (4.11.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (3.7.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from beautifulsoup4->nbconvert->notebook>=5.6.0->jupyterthemes) (2.3.1)
# Requirement already satisfied: webencodings in /Users/gustavosganzerla/opt/anaconda3/envs/p3workshop/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Installing collected packages: ply, lesscpy, jupyterthemes
# Successfully installed jupyterthemes-0.20.0 lesscpy-0.15.0 ply-3.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6d/45yqywp91qgc1d20yl568s500000gn/T/ipykernel_60729/2511217484.py in <module>
# ----> 1 jt -l
#
# NameError: name 'jt' is not defined
